# %%
# pip install pyperclip must be done in your computers termnial first before we can use it. 
import pyperclip as pc # made up as pc for me to make caling this easier. Woul not use if working with others.

# %%
pc.copy("Hello") # copies to the computers clip board

# %%
pc.paste() # you can press CTRL + v and it will past from the computers clipboard
# Out:
# 'Hello'
