# %%
print('''
*******************************************************************************
          |                   |                  |                     |
 _________|________________.=""_;=.______________|_____________________|_______
|                   |  ,-"_,=""     `"=.|                  |
|___________________|__"=._o`"-._        `"=.______________|___________________
          |                `"=._o`"=._      _`"=._                     |
 _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
|                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
|___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
          |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
 _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
|                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
|___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
____/______/______/___|o;._    "      `".o|o_.--"    ;o;____/______/______/____
/______/______/______/_"=._o--._        ; | ;        ; ;/______/______/______/_
____/______/______/______/__"=._o--._   ;o|o;     _._;o;____/______/______/____
/______/______/______/______/____"=._o._; | ;_.--"o.--"_/______/______/______/_
____/______/______/______/______/_____"=.o|o_.--""___/______/______/______/____
/______/______/______/______/______/______/______/______/______/______/_____ /
*******************************************************************************
''')
print("Welcome to Treasure Island.")
print("Your mission is to find the treasure.") 

print("You are walking down a path and come to a fork in the road. Will you choose the left or the right path? \n")
path = input("left or right: \n")
if path == 'right' or path == 'Right':
    print("You have falling into a hole with spikes. \n *****GAME OVER*****")
elif path != 'left' and path != 'Left':
    print('We can only choose left or right \n*****GAME OVER*****')
else:
    print("""You continue down the path.\n After a while you come across a lake with an island in the middle of it,
          and we need to make another decision""")
    
    print("There seem to be a boat that comes once every hour. We can choose to wait for the boat or swim acrosss to the island ")
    path2 = input("Wait or swim?: \n")

    if path2 == 'swim' or path2 == 'Swim':
        print("""As we start to swim across to the island, we start to see a fin heading towards us.
              We try to swim away but it is too late.
              ATE BY A SHARK!
              *****GAME OVER*****""")
    elif path2 != 'wait' and path2 != 'Wait':
        print("We can only chose wait or swim.\n *****GAME OVER*****")
    else:
        print("""We take the boat to the island and see another path. The road is colored yellow, and we strat to head down the path.
        We come to the end of the path and see three doors. A red door, a yellow door, and a green door. Which doo should we go through?""")
        door_choice = input('Chose a door. Red, yellow, or green: \n')

        if door_choice == 'red' or door_choice == 'Red':
            print("""As we open the door, we instantly regret our decision, as we feel tremendous  heat heading towards us. 
            Fire shoots out and we are burned alive
            *****GAME OVER*****""")
        elif door_choice == 'green' or door_choice == 'Green':
            print("""As we enter the door, we see a beautiful field of flowers, and green grass.....
            But this is the land of the giants and we have been spotted! They block off the door and there is no escape. 
            We have become a Giants play toy for the rest of our lives!
            *****GAME OVER*****""")
        else:
            print("""As we enter the yellow door. We are filled with joy and hapiness and see what we came here for all along!
            We have found the treasure and we are filthy RICH!
            ****YOU WIN!!!****""")
# Out:
# *******************************************************************************
#           |                   |                  |                     |
#  _________|________________.=""_;=.______________|_____________________|_______
# |                   |  ,-"_,=""     `"=.|                  |
# |___________________|__"=._o`"-._        `"=.______________|___________________
#           |                `"=._o`"=._      _`"=._                     |
#  _________|_____________________:=._o "=._."_.-="'"=.__________________|_______
# |                   |    __.--" , ; `"=._o." ,-"""-._ ".   |
# |___________________|_._"  ,. .` ` `` ,  `"-._"-._   ". '__|___________________
#           |           |o`"=._` , "` `; .". ,  "-._"-._; ;              |
#  _________|___________| ;`-.o`"=._; ." ` '`."\` . "-._ /_______________|_______
# |                   | |o;    `"-.o`"=._``  '` " ,__.--o;   |
# |___________________|_| ;     (#) `-.o `"=.`_.--"_o.-; ;___|___________________
# ...
