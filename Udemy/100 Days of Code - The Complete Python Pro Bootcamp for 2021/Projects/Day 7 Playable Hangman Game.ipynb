# %%
# %store -r stages logo word_list

# %%
#Step 5

import random
# from replit import clear # will not work in jupyter note book but willl work on other IDEs. Clears past prints Really cool!

chosen_word = random.choice(word_list)
word_length = len(chosen_word)

end_of_game = False
lives = 6



print(logo)

#Testing code if needed. This will print out the answer
# print(f'Pssst, the solution is {chosen_word}.')


display = []
letters_guesed = []
for _ in range(word_length):
    display += "_"

while not end_of_game:
    guess = input("Guess a letter: ").lower()
    letters_guesed += guess
    print(f'So far we have guessed the following letters: {" ".join(letters_guesed)}\n')
#     clear() # uses replit and Clears past prints Really cool!
    
    if guess in display:
        print(f"You have alrady guessed the letter {guess} try again\n")
    
    #Check guessed letter
    for position in range(word_length):
        letter = chosen_word[position]
        if letter == guess:
            display[position] = letter

    #Check if user is wrong.
    if guess not in chosen_word:
        #TODO-5: - If the letter is not in the chosen_word, print out the letter and let them know it's not in the word.
        print(f'The letter {guess} is not in the word.\n ***You lose a life. {lives - 1} lives left*** \n')
        lives -= 1
        if lives == 0:
            end_of_game = True
            print(f"You lose.\n The correct word was...... {chosen_word}!!!!")

    #Join all the elements in the list and turn it into a String.
    print(f"\n{' '.join(display)}")

    #Check if user has got all letters.
    if "_" not in display:
        end_of_game = True
        print("You win.")

    print(stages[lives])
# Out:
#
#  _
# | |
# | |__   __ _ _ __   __ _ _ __ ___   __ _ _ __
# | '_ \ / _` | '_ \ / _` | '_ ` _ \ / _` | '_ \
# | | | | (_| | | | | (_| | | | | | | (_| | | | |
# |_| |_|\__,_|_| |_|\__, |_| |_| |_|\__,_|_| |_|
#                     __/ |
#                    |___/
# Guess a letter: g
# So far we have guessed the following letters: g
#
# The letter g is not in the word.
#  ***You lose a life. 5 lives left***
#
#
# _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#       |
#       |
#       |
# ...
#
# Guess a letter: b
# So far we have guessed the following letters: g b
#
# The letter b is not in the word.
#  ***You lose a life. 4 lives left***
#
#
# _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#   |   |
#       |
#       |
# ...
#
# Guess a letter: s
# So far we have guessed the following letters: g b s
#
# The letter s is not in the word.
#  ***You lose a life. 3 lives left***
#
#
# _ _ _ _ _
#
#   +---+
#   |   |
#   O   |
#  /|   |
#       |
#       |
# ...
# Guess a letter: a
# ...
